# %% [markdown]
# <a href="https://colab.research.google.com/github/JediMasterKeith/FUNDAI-Laboratories-BASAN/blob/main/CS_FUNDAI_2026_Lab1_BASAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lab 1: Environment Onboarding

## Fundamentals of Artificial Intelligence

# **Name:** [Keith Lyndon G. Basan]
# **Course:** [CS-FUNDAI]
# **Section:** [09282-FUNDAI]
# **Date:** [08/18/2026]

# **GitHub URL:** [https://github.com/JediMasterKeith/FUNDAI-Laboratories-BASAN]

## Description
# This laboratory introduces the use of Google Colab and GitHub for AI laboratory activities. It also implements a simple intelligent agent.

# %%
import sys
import datetime

print("Python version:")
print(sys.version)

print("Current date:")
print(datetime.date.today())
# Out:
# Python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Current date:
# 2026-08-18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

folder_path = "/content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1"
os.makedirs(folder_path, exist_ok=True)

print("Folder ready:", folder_path)
# Out:
# Folder ready: /content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1

# %% [markdown]
# ## Simple Intelligent Agent
#
# This simple agent receives a room condition as a percept and produces an action.
#
# The agent follows a condition-action rule:
#
# - If the room is dirty, the agent cleans.
# - If the room is clean, the agent rests.
# - If the room condition is unknown, the agent inspects.

# %%
def simple_reflex_agent(room_condition):
  """
  A simple reflex agent that decides an action based on the room condition.
  """
  room_condition = room_condition.strip().lower()
  if room_condition == "dirty":
    return "CLEAN"
  elif room_condition == "clean":
    return "REST"
  else:
    return "INSPECT"

# %%
percepts = ["dirty", "clean", "dirty", "unknown"]

print("Simple Reflex Agent Test")
print("-" * 30)

for i, percept in enumerate(percepts, start=1):
  action = simple_reflex_agent(percept)
  print(f"Percept {i}: {percept:<8} -> Action: {action}")
# Out:
# Simple Reflex Agent Test
# ------------------------------
# Percept 1: dirty    -> Action: CLEAN
# Percept 2: clean    -> Action: REST
# Percept 3: dirty    -> Action: CLEAN
# Percept 4: unknown  -> Action: INSPECT

# %% [markdown]
# ## Performance Mesure
#
# A simple performance measure gives a score when the agent chooses the correct action for the given percept.

# %%
score = 0
total = len(percepts)

for percept in percepts:
    action = simple_reflex_agent(percept)

    if percept == "dirty" and action == "CLEAN":
        score += 1
    elif percept == "clean" and action == "REST":
        score += 1
    elif percept == "unknown" and action == "INSPECT":
        score += 1

print(f"Agent score: {score}/{total}")
# Out:
# Agent score: 4/4

# %% [markdown]
# ## Guide Questions and Answers
#
# ### 1. What is an intelligent agent?
# **Answer:** An intelligent agent is a system that perceives its environment  through sensors and acts upon that environment through actuators.
#
# ### 2. What are the sensors and actuators in this simple agent example?
# **Answer:** In this example, the sensor input is the room condition percept. The actuator output is the action such as CLEAN, REST, or INSPECT.
#
# ### 3. Why is documentation important in AI laboratory work?
# **Answer:** Documentation explains the purpose of the code, shows the results, and helps the instuctor evaluate the student's understanding.

# %% [markdown]
# ## Reflection
#
# ### Challenges Encountered
# - One challenge I encountered was ensuring that the conditions in the performance measure matched the actions returned by the agent. I initially had an extra space before "REST", which caused the "clean" percept to be marked incorrect and resulted in a score of 3/4. After identifying and correcting the error, the agent achieved a perfect score of 4/4.
#
# ## What I Learned
# - I learned how a simple reflex agent uses percepts and condition-action rules to choose an appropriate action. In this program, the agent responds to different room conditions by cleaning, resting, or inspecting. I also learned that small errors in conditions, such as an extra space in a string, can affect the program's results. The performance measure helped me verify whether the agent was making the correct decisions.
